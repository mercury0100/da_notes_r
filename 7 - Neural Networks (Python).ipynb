# %% [markdown]
# # 7. Neural Networks
#
# Neural networks (NNs) are a biologically-inspired programming paradigm that allows machines to learn from observational data. A NN is a parametric supervised model, that is a model that uses labeled training data to optimise its intrinsic parameters and produce a model. The power of these networks stems from the mathematical proof that an infinitely complex network can, in theory, represent any arbitrary function mapping feature variables to a target output. This means that unlike, for example, polynomial regression, we do not need to know anything about the functional form of the mapping we're trying to model in advance. This means that neural networks can learn highly complex mappings to perform tasks such as image recognition, speech recognition and natural language processing. Another benefit of NN's is their highly modular nature, meaning that countless network architectures are available for tackling specific problems, such as convolutional, recurrent and spiking NN's. The application of these architectures is the subject of deep learning and is far beyond the scope of this textbook. Here we introduce the basic concepts of NN's and explain the backpropagation algorithm which allows them to be optimised using training data.

# %% [markdown]
# ## 7.1 Perceptron
#
# A neural network is composed of layers of *neurons*, that is nodes in the network with an associated number called their *activation*. Each neuron is connected to the neurons in the adjacent layers through *synapses* with an associated *weight*, which defines the strength of the connection. The simplest possible neural network is called a perceptron, shown below, and is composed of three layers:
#
# <img src="img/perceptron.png" width=300>
#
# - Input Layer: The first layer is called the input layer, with one neuron for each feature variable in the training dataset. When a set of features is passed into the network, each neuron in the input layer has an _activation_ equal to the correponding variable. We can call the activations in the input layer of the example below $a^1_j$. The upper index represents the layer, while j indexes the neurons.
#
#
# - Hidden Layer: The neurons in the hidden layer are connected to each neuron in the input layer through synapses with associated weights. The activation of a neuron in the hidden layer is the sum of the activations in the previous layer multiplied by the weights of their connecting synapses, plus a _bias_ characteric of that hidden neuron. In the example perceptron, we can call the weights of the synapses between the input layer and the hidden layer $w^2_{jk}$, so that the weight of the synapse connecting the first neuron in the input layer to the second neuron in the hidden layer is $w^2_{12}$. We can similarly label the biases as $b^l_j$ so that the bias of the second neuron in the hidden layer is $b^2_2$. The activation of the second neuron in the hidden layer is then $a^2_2 = a^1_1 w^2_{12} + a^1_2 w^2_{22} + b^2_2$.
#
#
# - Output Layer: Neurons in the output layer have an activation corresponding to the predicted target value. The activation is again determined as the sum of the activations in the previous layer multiplied by the weights of their associated synapses, plus the bias. For a simple regression problem, the output layer will contain only one neuron. For a multiclass classification problem, the output layer will contain as many neurons as there are classes in the target variable. The predicted class then correponds to the output neuron with the largest activation.
#
# In this way, data introduced in the input layer is propagated forward through synapses into subsequent layers. The information from the input is reduced and encoded as a pattern in the next layer, and that information is processed again and encoded in the layer after that, until the output layer generates a prediction of what the input data represents. The process of optimising the weights and biases of a network to achieve a desired output is known as training.
#
# Forward propagating neural networks with more than one layer are called **Multi-layer Perceptrons**, and are the main focus of this chapter.
#
# ## 7.2 Training as Convex Optimisation
#
# To measure its performance, the network uses an associated *cost* or *loss* function, which is some monotonically increasing function of the errors between the target values predicted by the model and the actual values in the training set.
#
# The loss of a network is a function of its parameters (weights and biases), and of the entire training dataset. If we imagine a network with just two parameters (x and y), then we can imagine a cost associated with each combination of x and y for a given training set, which we can associate with the coordinate z. The loss is then a surface in 3D space, as shown in the figure below. The process of *optimising* the network corresponds to finding the combination of parameters (x and y) that correspond to the *global minimum* of the surface z.
#
# In reality, there are far more than two parameters for any neural network model, so z is generally a hypersurface in n+1-dimensional space for n parameters, however the principle of finding the combination of parameters that minimises the loss function remains the same.
#
# <img src="img/convex-optimisation.png" width=600>
#
# Finding the minimum is done through a process called gradient descent. The gradient is a *vector* with direction parallel to the path of steepest descent and magnitude proportional to the change in loss caused by an infinitesimal step in that direction. At each training iteration, we calculate the gradient for the current combination of parameters, and change those parameters slightly along the direction of steepest descent. If the vector of parameters is $\mathbf v$, the gradient descent algorithm works as follows:
#
# 1. For current parameters $\mathbf v_t$, calculate the gradient $\nabla loss(\mathbf v_t)$
# 2. Update the parameters according to the gradient $\mathbf v_{t+1} = \mathbf v_t - \alpha \nabla loss(\mathbf v_t)$
# 3. Repeat until maximum iterations, or gradient falls below a preset threshold.
#
# The symbol $\nabla$ represents the gradient operator, while the subscript $t$ in $\mathbf v_t$ represents the iteration number. $\alpha$ is a parameter controlling the size of the step taken at each iteration, called learning rate.
#
# In neural networks, finding the path of gradient descent is done through an algorithm called backpropagation.
#
# The most commonly used cost functions are the Mean Squared Error (quadratic cost) and Cross-Entropy. A quadratic cost function can exhibit large flat areas far from the optimum, leading to longer learning times since the gradient in these areas is very small. Cross-entropy mitigates this effect, maximising the gradient even when random initialisation of the network produces parameters that are far from the minimum.
#
# There are three general types of gradient descent in neural networks:
#
# - Stochastic Gradient Descent (SGD): The gradient at each iteration is estimated using just one training example.
# - Mini-batch Gradient Descent: The gradient at each iteration is estimated using a small sample of training examples.
# - Batch Gradient Descent: The gradient at each iteration is calculated using all training examples.
#
# Since gradient descent follows the steepest path to the closest minimum, it's possible for the algorithm to get stuck in *local minima* that are far from the global optimum. For this reason, adding randomness to the path of descent using stochastic and mini-batch methods can help ensure that the algorithm converges on a global minimum.
#
# ## 7.3 Nonlinearity and Activation Functions
#
# So far, everything we've seen has been a linear operation of the input data. Activations are a *linear combination* of the activations in the previous layer. Like in linear regression, we multiply the input variables by coefficients and add a bias (or intercept) when propagating information forward through the network. In order to learn complex, nonlinear functions, we need to introduce nonlinearities into our model. Enter the activation function.
#
# Activation functions are nonlinear functions that take the weighted sum of activations in the previous layer (plus the bias) as input and return the activation of a neuron. If the activation function for the hidden layer in the perceptron above is $\sigma(x)$, then the activation of the second neuron in the hidden layer becomes $a^h_2 = \sigma(a^i_1 w^i_{12} + a^i_2 w^i_{22} + b^h_2)$.
#
# Many different activation functions are commonly used, and are presented in the table below. The activation functions have different strengths and weaknesses.
#
# <img src="img/activation.png" width=600>
#
# The **sigmoid** and **tanh** activation functions confine the activations of neurons to a fixed interval, which is useful for avoiding exploding activations and is particularly attractive for classification problems where we want a value between 0 and 1. However, they are computationally expensive to compute during training, as are their gradients.
#
# The **ReLU** activation function, on the other hand, is extremely easy to evaluate, and the gradient is a simple step function. Both the sigmoid and ReLU activation functions have the added issue of *bias shift*, where the strictly positive activation causes large biases in subsequent layers to slow down learning. All three of these activations also have the issue of vanishing gradient, where neurons with very positive or very negative activations have a near-zero gradient. This means the weights associated with those neurons will cease to change significantly at each training iteration, leading to *dead neurons*.
#
# **Leaky ReLU** addresses the vanishing gradient issue by introducing a small gradient for activations below 0. However, leaky ReLU and ReLU can still have a difficult time identifying true nonlinearities (in the sense of curvature) as they are not truly nonlinear (they are stepwise linear functions). Conversely, true nonlinear functions like tanh and the sigmoid can have trouble identifying linear relationships, while for ReLU or leaky ReLU it's very easy. the **ELU** activation function combines the best of both worlds by introducing a nonlinear gradient below zero while also avoiding the vanishing gradient problem. Its main limitation is the computation involved in evaluating the function below zero.
#
# A **maxout** layer is simply a layer where the activation function is the maximum of the inputs. This is particularly useful when using a regularisation method called dropout. We will talk more about dropout and regularisation further on.

# %% [markdown]
# ## 7.4 Overfitting and Regularisation in Neural Networks: L1, L2 and Dropout
#
# Fundamental to the process of building models is the assumption of uncorrelated noise and the central-limit theorem. The former tells us that noise of a system is random with zero-mean and is unrelated to the signal. The latter tells us that we can view the noise as deriving from a normal distribution. In principle, regression and classification models should have sufficient data to *average out* the noise and learn the underlying signal. This is why having a sufficiently large dataset is so important to building generalisable models.
#
# Since a sufficiently complex neural network can theoretically model any function, it can be extremely easy to overfit the model such that it learns the noise and loses its ability to generalise to new data. To mitigate this, we can restrict the complexity of the network (number of layers, number of neurons) or we can artificially inflate the training data.
#
# There are also many regularisation methods that can be understood as penalising roughness in the model. One common cause of overfitting is collinearity in the input data, since it creates more degrees of freedom along a certain dimension to overcomplicate the model. L1 and L2 regularisation are two methods of addressing colinearity in neural networks that penalise large synaptic weights by adding a term to the cost function.
#
# ### 7.4.1 L2 Regularisation
#
# A regression model that uses L2 regularisation is called **Ridge regression**, and includes the “squared magnitude” of coefficients as penalty term to the loss function. The L2 regularization element which penalises large weights is:
#
# $$\lambda \sum_{i,j,k=1}^{n,m,p}(w^i_{jk})^2$$
#
# Here, if lambda is zero then we get back the regular cost function. Ridge regression shrinks the weights of the model and it helps to reduce complexity and multi-collinearity
#
# ### 7.4.2 L1 Regularisation
#
# A regression model that uses L1 regularization technique is called **Lasso regression**. Lasso Regression (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.
#
# $$\lambda \sum_{i,j,k=1}^{n,m,p}|w^i_{jk}|$$
#
# The key difference between these techniques is that Lasso shrinks the less important feature’s coefficient to zero, thus removing some feature altogether. So Lasso regression not only helps mitigate over-fitting, but also aids with feature selection where the are a large number of input variables.
#
# ### 7.4.3 Dropout
#
# Another cause of over-fitting in neural networks is the development of co-dependency between neurons, which can lead to inefficiencies in the network and overfitting. A simple solution to this is to randomly switch off a portion of neurons in hidden layers during forwards and backwards passes, mimicking unavailable pathways and forcing some redundancy in the system. This means neurons cannot develop co-dependent tendencies as a dependent neuron may be inactive at some training iterations. This process is called dropout, and serves to mitigate both overfitting and inefficiency.
#
# ## 7.5 Learning Rate Optimisation and Momentum
#
# At each iteration of the backpropagation algorithm, weights and biases of the network are adjusted according to the estimated error gradient. The magnitude of the changes applied to the model parameters is controlled by a coefficient called the *learning rate*. A learning rate that is too small can cause slow training times and can even cause the learning to stall. Learning rates that are too high, on the other hand, can cause the model to continuously leap over the global minimum and never converge.
#
# <img src="img/learning-rate.png" width=600>
# <center>Large learning rate (left) vs small learning rate (right) </center>
#
# To get the best of both worlds (fast learning rates and stable convergence) we can use *adaptive* learning rates, that is learning rates that change based on system characteristics. Many different adaptive learning rate algorithms exist. The most popular and most successful in most cases is called the ADAM optimiser.
#
# Part of the trouble with the backpropagation algorithm is that gradient descent can have a difficult time passing through saddle points and ravines, where the surface curves much more steeply in one dimension than in another. To mitigate this we can add a momentum term to the parameter updates, where a fraction of the previous update vector is added to subsequent updates.
#
# <img src="img/momentum.png" width=600>
# <center>Gradient descent traversing a ravine without momentum (left) and with momentum (right). </center>

# %% [markdown]
# ## 7.6 Neural Networks in R
#
# In R, we can easily prototype and train neural network models using the Keras library. Keras is a package built on top of the open source Tensorflow library for Python, originally built by Google AI. To install Keras, we need to first install the Miniconda package, which includes all the Python dependencies we need to run Tensorflow and Keras. Various releases of Miniconda can be found at the link below:
#
# https://docs.conda.io/en/latest/miniconda.html
#
# We then need to use the following commands:
#
# `install.packages('keras')`
#
# `library(keras)`
#
# `install_keras()`
#
# With that done, we can build a neural network to predict housing prices using the Baton Rouge dataset from chapter 5. First we load and inspect the data.

# %%
import pandas as pd

# Load the data. The first column is just a row index, so we use 'index_col='Unnamed: 0''
df = pd.read_csv('BatonRouge.csv', index_col='Unnamed: 0')

df.head()
# Out:
#     Price  SQFT  Bedrooms  Baths  Age  Occupancy  Pool  Fireplace  Waterfront  \
# 0   66500   741         1      1   18          1     1          1           0
# 1   66000   741         1      1   18          2     1          0           0
# 2   68500   790         1      1   18          1     0          1           0
# 3  102000  2783         2      2   18          1     0          1           0
# 4   54000  1165         2      1   35          2     0          0           0
#
#    DOM
# 0    6
# 1   23
# 2    8
# 3   50
# 4  190

# %% [markdown]
# Now, let's split the data into target and feature variables, scale the features and set aside a testing set for evaluation.

# %%
y = df.pop('Price')
X = df.copy()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

features = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.25, random_state=123)

print('Train Size', y_train.shape, y_train.shape)
print('Test Size', X_test.shape, y_test.shape)
# Out:
# Train Size (810,) (810,)
# Test Size (270, 9) (270,)

# %% [markdown]
# Now lets build our model in Keras. We will use a dense input layer with ReLU activation. The model will include 2 hidden layers with leaky ReLU activation.

# %%
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense, Activation, LeakyReLU


model = Sequential()
model.add(Dense(9, input_dim=X_train.shape[1], kernel_initializer="normal", activation='relu'))
model.add(Dense(5, kernel_initializer="normal", activation='relu',))
model.add(LeakyReLU())
model.add(Dense(1))

model.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 9)                 90
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 50
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 5)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we can compile the model and select global parameters, such as a loss function and an optimiser.

# %%
model.compile(loss='mse', optimizer=optimizers.Adam(lr=0.05), metrics=['mae'])
# Out:
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# The `fit()` function begins the training of our model, implementing backpropagation according to the optimiser selected previously. Here we train for 100 epochs using mini-batch descent (batch size of 10) and a validation split so we can assess the progress of our model.

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.3)
# Out:
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 567 samples, validate on 243 samples
# Epoch 1/100
# 567/567 [==============================] - 2s 4ms/step - loss: 39369744257.5802 - mean_absolute_error: 155519.6945 - val_loss: 30484741537.1852 - val_mean_absolute_error: 151304.3876
# Epoch 2/100
# 567/567 [==============================] - 0s 442us/step - loss: 38281845599.2663 - mean_absolute_error: 152789.6590 - val_loss: 28121032472.2304 - val_mean_absolute_error: 144941.6398
# Epoch 3/100
# 567/567 [==============================] - 0s 354us/step - loss: 33584013080.8325 - mean_absolute_error: 140225.3743 - val_loss: 21133168732.7078 - val_mean_absolute_error: 124598.1999
# Epoch 4/100
# 567/567 [==============================] - 0s 287us/step - loss: 22908964998.5467 - mean_absolute_error: 110401.2968 - val_loss: 10286543853.0370 - val_mean_absolute_error: 84223.1803
# Epoch 5/100
# 567/567 [==============================] - 0s 285us/step - loss: 12206887053.7707 - mean_absolute_error: 67950.4526 - val_loss: 3735395449.1523 - val_mean_absolute_error: 43540.5332
# Epoch 6/100
# 567/567 [==============================] - 0s 280us/step - loss: 8069432077.5450 - mean_absolute_error: 47177.1400 - val_loss: 2870062396.5761 - val_mean_absolute_error: 38186.9983
# Epoch 7/100
# 567/567 [==============================] - 0s 332us/step - loss: 7208733025.5238 - mean_absolute_error: 44405.9295 - val_loss: 2759861661.7613 - val_mean_absolute_error: 37218.4803
# Epoch 8/100
# 567/567 [==============================] - 0s 299us/step - loss: 6797834459.2028 - mean_absolute_error: 44217.9183 - val_loss: 2729133636.2140 - val_mean_absolute_error: 36295.4256
# Epoch 9/100
# 567/567 [==============================] - 0s 272us/step - loss: 6615950275.7249 - mean_absolute_error: 40862.6319 - val_loss: 2567868360.9547 - val_mean_absolute_error: 34706.0397
# Epoch 10/100
# 567/567 [==============================] - 0s 276us/step - loss: 6262867495.9577 - mean_absolute_error: 41947.1120 - val_loss: 2718066892.6420 - val_mean_absolute_error: 35336.0021
# Epoch 11/100
# 567/567 [==============================] - 0s 269us/step - loss: 6096365356.8113 - mean_absolute_error: 40858.5350 - val_loss: 2591239189.8601 - val_mean_absolute_error: 33930.6315
# Epoch 12/100
# 567/567 [==============================] - 0s 279us/step - loss: 5927896010.0459 - mean_absolute_error: 39170.0517 - val_loss: 2574781974.2551 - val_mean_absolute_error: 33618.8426
# Epoch 13/100
# 567/567 [==============================] - 0s 282us/step - loss: 5811593510.6032 - mean_absolute_error: 38530.0468 - val_loss: 2575262321.3498 - val_mean_absolute_error: 33503.0113
# Epoch 14/100
# 567/567 [==============================] - 0s 278us/step - loss: 5710817368.8325 - mean_absolute_error: 39096.2168 - val_loss: 2609607165.2675 - val_mean_absolute_error: 33478.2094
# Epoch 15/100
# 567/567 [==============================] - 0s 276us/step - loss: 5619257272.1552 - mean_absolute_error: 37849.2854 - val_loss: 2602531544.0000 - val_mean_absolute_error: 33261.6922
# Epoch 16/100
# 567/567 [==============================] - 0s 275us/step - loss: 5515186984.5220 - mean_absolute_error: 37277.1426 - val_loss: 2503695498.2387 - val_mean_absolute_error: 32372.4513
# Epoch 17/100
# 567/567 [==============================] - 0s 285us/step - loss: 5497911186.6243 - mean_absolute_error: 38620.2858 - val_loss: 2621250213.3498 - val_mean_absolute_error: 32975.2802
# Epoch 18/100
# 567/567 [==============================] - 0s 289us/step - loss: 5373013298.1446 - mean_absolute_error: 36603.5672 - val_loss: 2512654166.7984 - val_mean_absolute_error: 32156.0828
# Epoch 19/100
# 567/567 [==============================] - 0s 277us/step - loss: 5295921481.8201 - mean_absolute_error: 37381.6710 - val_loss: 2650903533.3498 - val_mean_absolute_error: 33004.0611
# Epoch 20/100
# 567/567 [==============================] - 0s 277us/step - loss: 5207682555.1464 - mean_absolute_error: 36342.4405 - val_loss: 2527542709.5802 - val_mean_absolute_error: 32032.7609
# Epoch 21/100
# 567/567 [==============================] - 0s 278us/step - loss: 5171992400.9312 - mean_absolute_error: 36884.7445 - val_loss: 2556801754.5021 - val_mean_absolute_error: 32158.5071
# Epoch 22/100
# 567/567 [==============================] - 0s 295us/step - loss: 5140508048.7055 - mean_absolute_error: 35777.9617 - val_loss: 2514465978.5679 - val_mean_absolute_error: 31798.3401
# Epoch 23/100
# 567/567 [==============================] - 0s 271us/step - loss: 5138872545.5238 - mean_absolute_error: 35093.4577 - val_loss: 2499229382.7901 - val_mean_absolute_error: 31665.9196
# Epoch 24/100
# 567/567 [==============================] - 0s 292us/step - loss: 5005691357.2346 - mean_absolute_error: 36384.8670 - val_loss: 2647999568.9136 - val_mean_absolute_error: 32522.2095
# Epoch 25/100
# 567/567 [==============================] - 0s 277us/step - loss: 5003238233.5097 - mean_absolute_error: 36168.3529 - val_loss: 2691730191.1111 - val_mean_absolute_error: 32662.6197
# Epoch 26/100
# 567/567 [==============================] - 0s 271us/step - loss: 4969263408.1975 - mean_absolute_error: 35998.0668 - val_loss: 2648229701.1523 - val_mean_absolute_error: 32408.7672
# Epoch 27/100
# 567/567 [==============================] - 0s 276us/step - loss: 4954494271.3228 - mean_absolute_error: 34643.8840 - val_loss: 2536218496.9053 - val_mean_absolute_error: 31788.5933
# Epoch 28/100
# 567/567 [==============================] - 0s 273us/step - loss: 4789462525.2910 - mean_absolute_error: 35413.0979 - val_loss: 2708647329.8025 - val_mean_absolute_error: 32571.8096
# Epoch 29/100
# 567/567 [==============================] - 0s 277us/step - loss: 4802373912.5503 - mean_absolute_error: 34850.5449 - val_loss: 2660798654.9053 - val_mean_absolute_error: 32264.9884
# Epoch 30/100
# 567/567 [==============================] - 0s 270us/step - loss: 4716982650.0176 - mean_absolute_error: 35309.3300 - val_loss: 2746928373.4897 - val_mean_absolute_error: 32646.2239
# Epoch 31/100
# 567/567 [==============================] - 0s 286us/step - loss: 4710070603.1746 - mean_absolute_error: 34839.8321 - val_loss: 2783330878.5514 - val_mean_absolute_error: 32794.7331
# Epoch 32/100
# 567/567 [==============================] - 0s 291us/step - loss: 4643594432.3951 - mean_absolute_error: 35316.5824 - val_loss: 2694481782.3868 - val_mean_absolute_error: 32425.8450
# Epoch 33/100
# 567/567 [==============================] - 0s 374us/step - loss: 4642092745.0300 - mean_absolute_error: 34952.9626 - val_loss: 2691901777.4486 - val_mean_absolute_error: 32357.1081
# Epoch 34/100
# 567/567 [==============================] - 0s 423us/step - loss: 4584618298.2434 - mean_absolute_error: 34263.0584 - val_loss: 2719138189.7366 - val_mean_absolute_error: 32351.2402
# Epoch 35/100
# 567/567 [==============================] - 0s 447us/step - loss: 4585817780.2610 - mean_absolute_error: 34222.1491 - val_loss: 2774757001.4403 - val_mean_absolute_error: 32521.9954
# Epoch 36/100
# 567/567 [==============================] - 0s 370us/step - loss: 4509446439.3086 - mean_absolute_error: 34450.7209 - val_loss: 2716314788.2058 - val_mean_absolute_error: 32291.1007
# Epoch 37/100
# 567/567 [==============================] - 0s 375us/step - loss: 4556666601.5379 - mean_absolute_error: 33683.3740 - val_loss: 2848732662.3128 - val_mean_absolute_error: 32744.2097
# Epoch 38/100
# 567/567 [==============================] - 0s 334us/step - loss: 4476091907.3862 - mean_absolute_error: 34475.2863 - val_loss: 2780906394.5432 - val_mean_absolute_error: 32394.5414
# Epoch 39/100
# 567/567 [==============================] - 0s 262us/step - loss: 4425113857.2981 - mean_absolute_error: 34306.2832 - val_loss: 2843453887.1193 - val_mean_absolute_error: 32667.6169
# Epoch 40/100
# 567/567 [==============================] - 0s 269us/step - loss: 4402289443.5556 - mean_absolute_error: 33912.6347 - val_loss: 2848285750.7819 - val_mean_absolute_error: 32623.3671
# Epoch 41/100
# 567/567 [==============================] - 0s 277us/step - loss: 4373264525.5450 - mean_absolute_error: 33858.5082 - val_loss: 2896586656.3045 - val_mean_absolute_error: 32701.6449
# Epoch 42/100
# 567/567 [==============================] - 0s 301us/step - loss: 4315314866.2857 - mean_absolute_error: 33789.3286 - val_loss: 2850570417.1276 - val_mean_absolute_error: 32474.5563
# Epoch 43/100
# 567/567 [==============================] - 0s 268us/step - loss: 4297219352.3810 - mean_absolute_error: 33500.5097 - val_loss: 2915211753.8189 - val_mean_absolute_error: 32676.3912
# Epoch 44/100
# 567/567 [==============================] - 0s 271us/step - loss: 4288858507.1746 - mean_absolute_error: 34196.5474 - val_loss: 2935933301.3992 - val_mean_absolute_error: 32717.6172
# Epoch 45/100
# 567/567 [==============================] - 0s 262us/step - loss: 4250860606.7584 - mean_absolute_error: 33307.2980 - val_loss: 2805264904.8230 - val_mean_absolute_error: 32157.8144
# Epoch 46/100
# 567/567 [==============================] - 0s 264us/step - loss: 4267250300.6702 - mean_absolute_error: 34145.0186 - val_loss: 2957443420.1235 - val_mean_absolute_error: 32733.6476
# Epoch 47/100
# 567/567 [==============================] - 0s 259us/step - loss: 4202212680.8042 - mean_absolute_error: 33228.4522 - val_loss: 2954775361.4486 - val_mean_absolute_error: 32647.4079
# Epoch 48/100
# 567/567 [==============================] - 0s 260us/step - loss: 4178940244.0917 - mean_absolute_error: 33592.6135 - val_loss: 3059411474.7243 - val_mean_absolute_error: 33044.8201
# Epoch 49/100
# 567/567 [==============================] - 0s 257us/step - loss: 4141075762.3422 - mean_absolute_error: 33368.2695 - val_loss: 2967618495.8601 - val_mean_absolute_error: 32677.6548
# Epoch 50/100
# 567/567 [==============================] - 0s 277us/step - loss: 4089587662.7866 - mean_absolute_error: 33602.4275 - val_loss: 3058683319.0123 - val_mean_absolute_error: 32896.6270
# Epoch 51/100
# 567/567 [==============================] - 0s 314us/step - loss: 4088313476.6279 - mean_absolute_error: 32893.8415 - val_loss: 3040020738.3457 - val_mean_absolute_error: 32755.5117
# Epoch 52/100
# 567/567 [==============================] - 0s 266us/step - loss: 4123049304.3810 - mean_absolute_error: 33501.2893 - val_loss: 2924511962.9959 - val_mean_absolute_error: 32227.1581
# Epoch 53/100
# 567/567 [==============================] - 0s 262us/step - loss: 4080425754.9206 - mean_absolute_error: 33795.1087 - val_loss: 3183229543.2428 - val_mean_absolute_error: 33206.1970
# Epoch 54/100
# 567/567 [==============================] - 0s 258us/step - loss: 3994075334.2081 - mean_absolute_error: 32944.3369 - val_loss: 3060602001.0370 - val_mean_absolute_error: 32691.6729
# Epoch 55/100
# 567/567 [==============================] - 0s 262us/step - loss: 3997090969.2840 - mean_absolute_error: 32945.2516 - val_loss: 3043088476.3292 - val_mean_absolute_error: 32558.2200
# Epoch 56/100
# 567/567 [==============================] - 0s 265us/step - loss: 3985675693.4885 - mean_absolute_error: 32593.8449 - val_loss: 3227757848.3868 - val_mean_absolute_error: 33282.1697
# Epoch 57/100
# 567/567 [==============================] - 0s 265us/step - loss: 3938844963.7249 - mean_absolute_error: 33638.7455 - val_loss: 3227209540.8724 - val_mean_absolute_error: 33197.5757
# Epoch 58/100
# 567/567 [==============================] - 0s 270us/step - loss: 3896048784.4515 - mean_absolute_error: 33025.0859 - val_loss: 3153433768.5103 - val_mean_absolute_error: 32951.0511
# Epoch 59/100
# 567/567 [==============================] - 0s 268us/step - loss: 3966458821.0794 - mean_absolute_error: 33225.9633 - val_loss: 3176770566.7160 - val_mean_absolute_error: 32966.9471
# Epoch 60/100
# 567/567 [==============================] - 0s 269us/step - loss: 3936832152.6067 - mean_absolute_error: 32313.0401 - val_loss: 3176617635.8930 - val_mean_absolute_error: 32943.0359
# Epoch 61/100
# 567/567 [==============================] - 0s 271us/step - loss: 3917350260.8254 - mean_absolute_error: 33708.8064 - val_loss: 3245744763.0453 - val_mean_absolute_error: 33095.8698
# Epoch 62/100
# 567/567 [==============================] - 0s 273us/step - loss: 3862458249.2557 - mean_absolute_error: 32355.6798 - val_loss: 3245099785.8436 - val_mean_absolute_error: 33112.7758
# Epoch 63/100
# 567/567 [==============================] - 0s 276us/step - loss: 3784188315.9083 - mean_absolute_error: 32616.4093 - val_loss: 3290108546.8477 - val_mean_absolute_error: 33279.8125
# Epoch 64/100
# 567/567 [==============================] - 0s 313us/step - loss: 3806590569.3122 - mean_absolute_error: 33121.3559 - val_loss: 3324618907.7695 - val_mean_absolute_error: 33311.9678
# Epoch 65/100
# 567/567 [==============================] - 0s 271us/step - loss: 3839735947.0617 - mean_absolute_error: 32665.8663 - val_loss: 3375265082.3539 - val_mean_absolute_error: 33438.1547
# Epoch 66/100
# 567/567 [==============================] - 0s 269us/step - loss: 3739343969.7496 - mean_absolute_error: 32802.3694 - val_loss: 3378741614.7490 - val_mean_absolute_error: 33385.5061
# Epoch 67/100
# 567/567 [==============================] - 0s 267us/step - loss: 3785887132.8959 - mean_absolute_error: 32810.6018 - val_loss: 3478044633.8765 - val_mean_absolute_error: 33710.3575
# Epoch 68/100
# 567/567 [==============================] - 0s 272us/step - loss: 3751760462.5608 - mean_absolute_error: 32541.9929 - val_loss: 3323296419.2757 - val_mean_absolute_error: 33128.0463
# Epoch 69/100
# 567/567 [==============================] - 0s 272us/step - loss: 3697204365.7143 - mean_absolute_error: 32762.1816 - val_loss: 3451631858.6008 - val_mean_absolute_error: 33458.4269
# Epoch 70/100
# 567/567 [==============================] - 0s 272us/step - loss: 3687904788.2046 - mean_absolute_error: 32264.0750 - val_loss: 3419615161.6461 - val_mean_absolute_error: 33294.0469
# Epoch 71/100
# 567/567 [==============================] - 0s 272us/step - loss: 3648286217.8201 - mean_absolute_error: 32655.5652 - val_loss: 3524032525.2675 - val_mean_absolute_error: 33621.0758
# Epoch 72/100
# 567/567 [==============================] - 0s 282us/step - loss: 3643122155.6825 - mean_absolute_error: 32452.7028 - val_loss: 3485410033.1523 - val_mean_absolute_error: 33426.8137
# Epoch 73/100
# 567/567 [==============================] - 0s 273us/step - loss: 3641471474.8783 - mean_absolute_error: 32888.6178 - val_loss: 3553264458.6667 - val_mean_absolute_error: 33600.0828
# Epoch 74/100
# 567/567 [==============================] - 0s 267us/step - loss: 3569468288.7055 - mean_absolute_error: 32727.7807 - val_loss: 3523898451.1276 - val_mean_absolute_error: 33437.0765
# Epoch 75/100
# 567/567 [==============================] - 0s 269us/step - loss: 3567268807.4674 - mean_absolute_error: 32308.9576 - val_loss: 3520889364.5432 - val_mean_absolute_error: 33327.6958
# Epoch 76/100
# 567/567 [==============================] - 0s 267us/step - loss: 3584062665.7637 - mean_absolute_error: 32189.5670 - val_loss: 3633310786.3045 - val_mean_absolute_error: 33670.6104
# Epoch 77/100
# 567/567 [==============================] - 0s 271us/step - loss: 3579766806.4056 - mean_absolute_error: 32513.2773 - val_loss: 3347448866.4691 - val_mean_absolute_error: 32783.0781
# Epoch 78/100
# 567/567 [==============================] - 0s 270us/step - loss: 3480226752.0564 - mean_absolute_error: 32270.3987 - val_loss: 3764348699.1605 - val_mean_absolute_error: 33837.9468
# Epoch 79/100
# 567/567 [==============================] - 0s 271us/step - loss: 3509692980.9383 - mean_absolute_error: 32619.6525 - val_loss: 3611324100.4774 - val_mean_absolute_error: 33321.1662
# Epoch 80/100
# 567/567 [==============================] - 0s 276us/step - loss: 3462879338.1587 - mean_absolute_error: 32074.5141 - val_loss: 3534563504.6914 - val_mean_absolute_error: 33005.7359
# Epoch 81/100
# 567/567 [==============================] - 0s 273us/step - loss: 3547234183.6190 - mean_absolute_error: 32708.0612 - val_loss: 3495407175.2428 - val_mean_absolute_error: 32872.7700
# Epoch 82/100
# 567/567 [==============================] - 0s 268us/step - loss: 3442440027.3721 - mean_absolute_error: 31894.5309 - val_loss: 3574332419.2922 - val_mean_absolute_error: 32956.2287
# Epoch 83/100
# 567/567 [==============================] - 0s 271us/step - loss: 3444483340.6420 - mean_absolute_error: 32084.0489 - val_loss: 3664319165.1358 - val_mean_absolute_error: 33175.4963
# Epoch 84/100
# 567/567 [==============================] - 0s 289us/step - loss: 3455891340.7548 - mean_absolute_error: 32642.8002 - val_loss: 3520040280.9547 - val_mean_absolute_error: 32808.0553
# Epoch 85/100
# 567/567 [==============================] - 0s 267us/step - loss: 3438276371.4145 - mean_absolute_error: 31963.0077 - val_loss: 3654103720.3621 - val_mean_absolute_error: 33001.7775
# Epoch 86/100
# 567/567 [==============================] - 0s 266us/step - loss: 3484251427.4427 - mean_absolute_error: 32012.5544 - val_loss: 3825228275.2593 - val_mean_absolute_error: 33456.2783
# Epoch 87/100
# 567/567 [==============================] - 0s 277us/step - loss: 3410344537.2840 - mean_absolute_error: 32174.2154 - val_loss: 3806467954.6996 - val_mean_absolute_error: 33344.3068
# Epoch 88/100
# 567/567 [==============================] - 0s 267us/step - loss: 3350908919.5908 - mean_absolute_error: 31994.5781 - val_loss: 3725116589.0370 - val_mean_absolute_error: 33113.5627
# Epoch 89/100
# 567/567 [==============================] - 0s 287us/step - loss: 3332262940.3034 - mean_absolute_error: 31971.1513 - val_loss: 3728843121.7778 - val_mean_absolute_error: 33075.7736
# Epoch 90/100
# 567/567 [==============================] - 0s 272us/step - loss: 3332090095.7460 - mean_absolute_error: 31856.9315 - val_loss: 3564292907.1276 - val_mean_absolute_error: 32656.1192
# Epoch 91/100
# 567/567 [==============================] - 0s 266us/step - loss: 3367621792.6772 - mean_absolute_error: 32114.4922 - val_loss: 3749994457.5473 - val_mean_absolute_error: 33012.6772
# Epoch 92/100
# 567/567 [==============================] - 0s 272us/step - loss: 3317156913.6649 - mean_absolute_error: 32064.1264 - val_loss: 3628134414.1564 - val_mean_absolute_error: 32763.0051
# Epoch 93/100
# 567/567 [==============================] - 0s 275us/step - loss: 3488563810.4268 - mean_absolute_error: 32894.9476 - val_loss: 3695702328.0329 - val_mean_absolute_error: 32919.7257
# Epoch 94/100
# 567/567 [==============================] - 0s 275us/step - loss: 3300456787.0758 - mean_absolute_error: 31533.6355 - val_loss: 3635309121.2510 - val_mean_absolute_error: 32700.5270
# Epoch 95/100
# 567/567 [==============================] - 0s 276us/step - loss: 3296740129.0723 - mean_absolute_error: 31614.2552 - val_loss: 3893105320.3621 - val_mean_absolute_error: 33253.5854
# Epoch 96/100
# 567/567 [==============================] - 0s 276us/step - loss: 3256515768.7760 - mean_absolute_error: 32389.6934 - val_loss: 3794060941.6955 - val_mean_absolute_error: 32905.1986
# Epoch 97/100
# 567/567 [==============================] - 0s 303us/step - loss: 3241626922.3280 - mean_absolute_error: 31538.7444 - val_loss: 3629404090.6667 - val_mean_absolute_error: 32600.2149
# Epoch 98/100
# 567/567 [==============================] - 0s 269us/step - loss: 3209866616.2116 - mean_absolute_error: 32074.2588 - val_loss: 3981027227.1934 - val_mean_absolute_error: 33226.3869
# Epoch 99/100
# 567/567 [==============================] - 0s 271us/step - loss: 3282544444.0494 - mean_absolute_error: 31930.0359 - val_loss: 3705574246.7160 - val_mean_absolute_error: 32699.3321
# Epoch 100/100
# 567/567 [==============================] - 0s 266us/step - loss: 3180556109.5450 - mean_absolute_error: 31487.1900 - val_loss: 3999816051.3580 - val_mean_absolute_error: 33215.4762

# %% [markdown]
# Now let's plot the history of loss and validation loss

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

plt.figure(figsize=(12,7))
sns.scatterplot(x = range(0,100), y = history.history['loss'], color='black')
sns.lineplot(x = range(0,100), y = history.history['loss'])
sns.scatterplot(x = range(0,100), y = history.history['val_loss'], color='black')
sns.lineplot(x = range(0,100), y = history.history['val_loss'])

# %% [markdown]
# We can also plot the MSE and validation MSE

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x = range(0,100), y = history.history['mean_absolute_error'], color='black')
sns.lineplot(x = range(0,100), y = history.history['mean_absolute_error'])
sns.scatterplot(x = range(0,100), y = history.history['val_mean_absolute_error'], color='black')
sns.lineplot(x = range(0,100), y = history.history['val_mean_absolute_error'])

# %% [markdown]
# Finally we can generate predictions from the test set and evaluate the model.

# %%
from sklearn.metrics import mean_absolute_error

predictions = model.predict(X_test)

mae = mean_absolute_error(y_test, predictions)

print("Total error: $%.2f" %mae)
# Out:
# Total error: $35916.77

# %% [markdown]
# Looking at the `Mean Absolute Error` plot above, we can see that during the final stages of training, the validation error starts to increase, while the training error continues to decrease. This is the signature of overfitting. We can try to mitigate this by either simplifying the model or using regularisation. Since our model is already quite simple and we don't have too many input features, we will use a combination of dropout and L2 regularisation.

# %%
from keras.models import Sequential
from keras import optimizers, regularizers
from keras.layers import Dense, Activation, LeakyReLU, Dropout


model = Sequential()
model.add(Dense(9, input_dim=X_train.shape[1], kernel_initializer="normal", activation='relu',
               kernel_regularizer=regularizers.l2(0.5)))
model.add(Dropout(0.2))
model.add(Dense(5, kernel_initializer="normal", kernel_regularizer=regularizers.l2(0.5)))
model.add(LeakyReLU())
model.add(Dense(1))

model.compile(loss='mse', optimizer=optimizers.Adam(lr=0.05), metrics=['mae'])

history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.3)

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

plt.figure(figsize=(12,7))
sns.scatterplot(x = range(0,100), y = history.history['loss'], color='black')
sns.lineplot(x = range(0,100), y = history.history['loss'])
sns.scatterplot(x = range(0,100), y = history.history['val_loss'], color='black')
sns.lineplot(x = range(0,100), y = history.history['val_loss'])
# Out:
# WARNING:tensorflow:From /Users/cooper/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 567 samples, validate on 243 samples
# Epoch 1/100
# 567/567 [==============================] - 2s 3ms/step - loss: 39261957316.8536 - mean_absolute_error: 155252.9819 - val_loss: 30106758219.8518 - val_mean_absolute_error: 150090.1576
# Epoch 2/100
# 567/567 [==============================] - 0s 343us/step - loss: 36786157936.4233 - mean_absolute_error: 147617.9195 - val_loss: 24539925107.8848 - val_mean_absolute_error: 132165.5874
# Epoch 3/100
# 567/567 [==============================] - 0s 347us/step - loss: 25943705672.2399 - mean_absolute_error: 113732.6609 - val_loss: 10546944183.3086 - val_mean_absolute_error: 78878.4775
# Epoch 4/100
# 567/567 [==============================] - 0s 344us/step - loss: 13454869095.3933 - mean_absolute_error: 61671.5973 - val_loss: 3352042851.5556 - val_mean_absolute_error: 39764.3307
# Epoch 5/100
# 567/567 [==============================] - 0s 398us/step - loss: 9007349653.8977 - mean_absolute_error: 48567.5405 - val_loss: 2473642865.2510 - val_mean_absolute_error: 34958.2378
# Epoch 6/100
# 567/567 [==============================] - 0s 338us/step - loss: 7304043521.1287 - mean_absolute_error: 46541.9062 - val_loss: 2369385033.3498 - val_mean_absolute_error: 33290.5803
# Epoch 7/100
# 567/567 [==============================] - 0s 339us/step - loss: 8672913613.3192 - mean_absolute_error: 47912.4115 - val_loss: 2331051792.5926 - val_mean_absolute_error: 32222.3349
# Epoch 8/100
# 567/567 [==============================] - 0s 343us/step - loss: 7549225082.5820 - mean_absolute_error: 46912.3816 - val_loss: 2303039413.4650 - val_mean_absolute_error: 31747.6305
# Epoch 9/100
# 567/567 [==============================] - 0s 360us/step - loss: 6277639774.4762 - mean_absolute_error: 44518.4409 - val_loss: 2423847073.3827 - val_mean_absolute_error: 32878.7951
# Epoch 10/100
# 567/567 [==============================] - 0s 353us/step - loss: 7774729227.6261 - mean_absolute_error: 44829.9599 - val_loss: 2267838393.2840 - val_mean_absolute_error: 30962.1434
# Epoch 11/100
# 567/567 [==============================] - 0s 347us/step - loss: 6391338271.0406 - mean_absolute_error: 44116.3805 - val_loss: 2323861635.2263 - val_mean_absolute_error: 31233.9801
# Epoch 12/100
# 567/567 [==============================] - 0s 349us/step - loss: 6498558983.2240 - mean_absolute_error: 44535.7753 - val_loss: 2308758375.9342 - val_mean_absolute_error: 30954.3608
# Epoch 13/100
# 567/567 [==============================] - 0s 353us/step - loss: 6936691155.6402 - mean_absolute_error: 45359.1826 - val_loss: 2342347389.2016 - val_mean_absolute_error: 30882.3415
# Epoch 14/100
# 567/567 [==============================] - 0s 352us/step - loss: 8727168052.7125 - mean_absolute_error: 45415.8859 - val_loss: 2372500752.5597 - val_mean_absolute_error: 31008.2497
# Epoch 15/100
# 567/567 [==============================] - 0s 355us/step - loss: 6784220198.3774 - mean_absolute_error: 44152.9636 - val_loss: 2346848833.2840 - val_mean_absolute_error: 30653.6187
# Epoch 16/100
# 567/567 [==============================] - 0s 346us/step - loss: 6693545033.8201 - mean_absolute_error: 45157.5739 - val_loss: 2478119066.2058 - val_mean_absolute_error: 31512.2796
# Epoch 17/100
# 567/567 [==============================] - 0s 353us/step - loss: 5970238502.6032 - mean_absolute_error: 43463.0003 - val_loss: 2489048077.7613 - val_mean_absolute_error: 31588.8103
# Epoch 18/100
# 567/567 [==============================] - 0s 346us/step - loss: 5693250682.5820 - mean_absolute_error: 42941.5330 - val_loss: 2526790814.7819 - val_mean_absolute_error: 31784.7744
# Epoch 19/100
# 567/567 [==============================] - 0s 353us/step - loss: 7654527995.2593 - mean_absolute_error: 46234.1302 - val_loss: 2367932772.0494 - val_mean_absolute_error: 30823.1188
# Epoch 20/100
# 567/567 [==============================] - 0s 358us/step - loss: 7505114459.6543 - mean_absolute_error: 45539.2747 - val_loss: 2359582255.7037 - val_mean_absolute_error: 30635.1571
# Epoch 21/100
# 567/567 [==============================] - 0s 351us/step - loss: 5951612183.5908 - mean_absolute_error: 43157.4449 - val_loss: 2443221400.5350 - val_mean_absolute_error: 31064.7779
# Epoch 22/100
# 567/567 [==============================] - 0s 364us/step - loss: 6275516078.9559 - mean_absolute_error: 44542.7423 - val_loss: 2509796514.3045 - val_mean_absolute_error: 31511.5907
# Epoch 23/100
# 567/567 [==============================] - 0s 350us/step - loss: 6610580002.9912 - mean_absolute_error: 44722.8292 - val_loss: 2443961147.4239 - val_mean_absolute_error: 31391.2490
# Epoch 24/100
# 567/567 [==============================] - 0s 343us/step - loss: 5474108934.3210 - mean_absolute_error: 41919.1621 - val_loss: 2508069555.2263 - val_mean_absolute_error: 31312.8132
# Epoch 25/100
# 567/567 [==============================] - 0s 343us/step - loss: 6710155486.4198 - mean_absolute_error: 42550.2011 - val_loss: 2470041968.5926 - val_mean_absolute_error: 31588.5202
# Epoch 26/100
# 567/567 [==============================] - 0s 372us/step - loss: 6709837942.0670 - mean_absolute_error: 44299.4258 - val_loss: 2617960371.5226 - val_mean_absolute_error: 32267.1155
# Epoch 27/100
# 567/567 [==============================] - 0s 347us/step - loss: 6720697798.8854 - mean_absolute_error: 45167.5687 - val_loss: 2593064728.3292 - val_mean_absolute_error: 31914.4161
# Epoch 28/100
# 567/567 [==============================] - 0s 346us/step - loss: 7164885712.5926 - mean_absolute_error: 44542.4149 - val_loss: 2508810200.8889 - val_mean_absolute_error: 31930.3805
# Epoch 29/100
# 567/567 [==============================] - 0s 341us/step - loss: 5892105062.3774 - mean_absolute_error: 43835.4406 - val_loss: 2587550988.3786 - val_mean_absolute_error: 31860.9198
# Epoch 30/100
# 567/567 [==============================] - 0s 387us/step - loss: 6197408966.4339 - mean_absolute_error: 42387.8086 - val_loss: 2581486633.6132 - val_mean_absolute_error: 32096.6970
# Epoch 31/100
# 567/567 [==============================] - 0s 334us/step - loss: 6627105127.3933 - mean_absolute_error: 43177.4008 - val_loss: 2556144562.0741 - val_mean_absolute_error: 31912.1547
# Epoch 32/100
# 567/567 [==============================] - 0s 336us/step - loss: 6099641179.8801 - mean_absolute_error: 43707.8057 - val_loss: 2590046738.9630 - val_mean_absolute_error: 32007.8208
# Epoch 33/100
# 567/567 [==============================] - 0s 333us/step - loss: 5845594583.8166 - mean_absolute_error: 41907.5199 - val_loss: 2791792077.5309 - val_mean_absolute_error: 32586.7769
# Epoch 34/100
# 567/567 [==============================] - 0s 338us/step - loss: 5720766342.2081 - mean_absolute_error: 42314.6885 - val_loss: 2796403445.2675 - val_mean_absolute_error: 32834.7988
# Epoch 35/100
# 567/567 [==============================] - 0s 342us/step - loss: 5125469186.4832 - mean_absolute_error: 43051.0679 - val_loss: 2773368578.0741 - val_mean_absolute_error: 32498.7579
# Epoch 36/100
# 567/567 [==============================] - 0s 337us/step - loss: 6652500554.4974 - mean_absolute_error: 45193.0003 - val_loss: 2713993745.1852 - val_mean_absolute_error: 32447.9241
# Epoch 37/100
# 567/567 [==============================] - 0s 333us/step - loss: 6428189085.1217 - mean_absolute_error: 44312.6432 - val_loss: 2688753702.1893 - val_mean_absolute_error: 32264.0973
# Epoch 38/100
# 567/567 [==============================] - 0s 346us/step - loss: 5877113129.9894 - mean_absolute_error: 41778.9082 - val_loss: 2732280903.3086 - val_mean_absolute_error: 32128.1261
# Epoch 39/100
# 567/567 [==============================] - 0s 351us/step - loss: 5390377914.0176 - mean_absolute_error: 43110.8826 - val_loss: 2705885412.8724 - val_mean_absolute_error: 32413.9738
# Epoch 40/100
# 567/567 [==============================] - 0s 346us/step - loss: 4729107533.2063 - mean_absolute_error: 42481.1696 - val_loss: 2744604944.0000 - val_mean_absolute_error: 32037.7146
# Epoch 41/100
# 567/567 [==============================] - 0s 345us/step - loss: 4471276351.0970 - mean_absolute_error: 40621.3393 - val_loss: 2818415378.6996 - val_mean_absolute_error: 32601.7427
# Epoch 42/100
# 567/567 [==============================] - 0s 346us/step - loss: 6124080129.5802 - mean_absolute_error: 43929.0856 - val_loss: 2931248515.6214 - val_mean_absolute_error: 32907.9816
# Epoch 43/100
# 567/567 [==============================] - 0s 347us/step - loss: 6499778368.1129 - mean_absolute_error: 43465.6496 - val_loss: 2789156715.2593 - val_mean_absolute_error: 32294.7641
# Epoch 44/100
# 567/567 [==============================] - 0s 344us/step - loss: 6521363676.7831 - mean_absolute_error: 44591.0105 - val_loss: 2758330830.3539 - val_mean_absolute_error: 31805.9895
# Epoch 45/100
# 567/567 [==============================] - 0s 337us/step - loss: 4641401992.1270 - mean_absolute_error: 41343.4105 - val_loss: 2851899269.9259 - val_mean_absolute_error: 32115.7786
# Epoch 46/100
# 567/567 [==============================] - 0s 348us/step - loss: 4948725419.7954 - mean_absolute_error: 44462.9067 - val_loss: 2943479655.6379 - val_mean_absolute_error: 32728.6717
# Epoch 47/100
# 567/567 [==============================] - 0s 330us/step - loss: 4324677755.5979 - mean_absolute_error: 41737.2396 - val_loss: 2943877609.4815 - val_mean_absolute_error: 33106.4099
# Epoch 48/100
# 567/567 [==============================] - 0s 339us/step - loss: 5445367156.9383 - mean_absolute_error: 43218.9720 - val_loss: 2895095617.5802 - val_mean_absolute_error: 32459.5873
# Epoch 49/100
# 567/567 [==============================] - 0s 332us/step - loss: 5362002685.9683 - mean_absolute_error: 42932.9465 - val_loss: 3019821359.3416 - val_mean_absolute_error: 32775.6798
# Epoch 50/100
# 567/567 [==============================] - 0s 337us/step - loss: 5111903471.7460 - mean_absolute_error: 43769.1624 - val_loss: 2893876355.9506 - val_mean_absolute_error: 33056.6274
# Epoch 51/100
# 567/567 [==============================] - 0s 331us/step - loss: 4302594900.4303 - mean_absolute_error: 41404.1768 - val_loss: 2884651042.1070 - val_mean_absolute_error: 31880.3803
# Epoch 52/100
# 567/567 [==============================] - 0s 332us/step - loss: 4636774932.6561 - mean_absolute_error: 41029.6465 - val_loss: 2928590185.4815 - val_mean_absolute_error: 32406.1657
# Epoch 53/100
# 567/567 [==============================] - 0s 352us/step - loss: 5202983035.7108 - mean_absolute_error: 42662.5349 - val_loss: 2837280491.5885 - val_mean_absolute_error: 32139.1722
# Epoch 54/100
# 567/567 [==============================] - 0s 337us/step - loss: 6900157892.2892 - mean_absolute_error: 43301.1840 - val_loss: 2825764488.0329 - val_mean_absolute_error: 32458.1505
# Epoch 55/100
# 567/567 [==============================] - 0s 363us/step - loss: 4201980306.2857 - mean_absolute_error: 40048.7703 - val_loss: 2987554312.6914 - val_mean_absolute_error: 32501.1286
# Epoch 56/100
# 567/567 [==============================] - 0s 368us/step - loss: 5581990584.5503 - mean_absolute_error: 42959.4320 - val_loss: 3006639905.5802 - val_mean_absolute_error: 32677.0311
# Epoch 57/100
# 567/567 [==============================] - 0s 331us/step - loss: 5085923038.1376 - mean_absolute_error: 41907.8743 - val_loss: 3043495377.7778 - val_mean_absolute_error: 32698.4932
# Epoch 58/100
# 567/567 [==============================] - 0s 328us/step - loss: 5138511247.3510 - mean_absolute_error: 41629.3281 - val_loss: 3133483945.7449 - val_mean_absolute_error: 33052.3992
# Epoch 59/100
# 567/567 [==============================] - 0s 339us/step - loss: 5264594178.4832 - mean_absolute_error: 41387.7087 - val_loss: 3044773654.1235 - val_mean_absolute_error: 32797.9458
# Epoch 60/100
# 567/567 [==============================] - 0s 336us/step - loss: 4910844405.0511 - mean_absolute_error: 41902.3696 - val_loss: 3244919412.1481 - val_mean_absolute_error: 33149.3802
# Epoch 61/100
# 567/567 [==============================] - 0s 335us/step - loss: 6400794334.1376 - mean_absolute_error: 43226.5950 - val_loss: 2963665714.1728 - val_mean_absolute_error: 32516.4832
# Epoch 62/100
# 567/567 [==============================] - 0s 337us/step - loss: 5282806304.7337 - mean_absolute_error: 42353.7078 - val_loss: 3150843374.0905 - val_mean_absolute_error: 32425.1117
# Epoch 63/100
# 567/567 [==============================] - 0s 341us/step - loss: 5431108578.4268 - mean_absolute_error: 43094.4549 - val_loss: 2918631555.0288 - val_mean_absolute_error: 32168.1986
# Epoch 64/100
# 567/567 [==============================] - 0s 328us/step - loss: 5728035968.6772 - mean_absolute_error: 43360.4813 - val_loss: 3119491125.4650 - val_mean_absolute_error: 32333.9686
# Epoch 65/100
# 567/567 [==============================] - 0s 328us/step - loss: 5464374425.2840 - mean_absolute_error: 42518.2876 - val_loss: 3288614263.5720 - val_mean_absolute_error: 33157.7802
# Epoch 66/100
# 567/567 [==============================] - 0s 334us/step - loss: 5213233047.4780 - mean_absolute_error: 40978.7790 - val_loss: 3381615255.0453 - val_mean_absolute_error: 33653.5130
# Epoch 67/100
# 567/567 [==============================] - 0s 333us/step - loss: 5914833230.3351 - mean_absolute_error: 44632.4295 - val_loss: 3164694130.9630 - val_mean_absolute_error: 33063.6265
# Epoch 68/100
# 567/567 [==============================] - 0s 327us/step - loss: 6117843699.5838 - mean_absolute_error: 44406.4357 - val_loss: 3181877589.3333 - val_mean_absolute_error: 33331.8418
# Epoch 69/100
# 567/567 [==============================] - 0s 351us/step - loss: 4579222932.7690 - mean_absolute_error: 42985.8566 - val_loss: 3091310985.7449 - val_mean_absolute_error: 32653.5432
# Epoch 70/100
# 567/567 [==============================] - 0s 340us/step - loss: 5524997818.8078 - mean_absolute_error: 41809.6300 - val_loss: 3171466650.6667 - val_mean_absolute_error: 32233.6514
# Epoch 71/100
# 567/567 [==============================] - 0s 339us/step - loss: 5734131534.3351 - mean_absolute_error: 42669.7849 - val_loss: 3372525605.6626 - val_mean_absolute_error: 32527.6498
# Epoch 72/100
# 567/567 [==============================] - 0s 350us/step - loss: 5706421299.4709 - mean_absolute_error: 43913.4915 - val_loss: 3331176777.2181 - val_mean_absolute_error: 32630.0689
# Epoch 73/100
# 567/567 [==============================] - 0s 334us/step - loss: 7271994423.0829 - mean_absolute_error: 45010.5922 - val_loss: 3111919571.2263 - val_mean_absolute_error: 32328.3478
# Epoch 74/100
# 567/567 [==============================] - 0s 331us/step - loss: 4964696485.9259 - mean_absolute_error: 41636.3526 - val_loss: 3111340276.7407 - val_mean_absolute_error: 32061.9417
# Epoch 75/100
# 567/567 [==============================] - 0s 358us/step - loss: 5050942661.3616 - mean_absolute_error: 40632.7831 - val_loss: 3104372039.1111 - val_mean_absolute_error: 31459.4430
# Epoch 76/100
# 567/567 [==============================] - 0s 396us/step - loss: 5304323637.9541 - mean_absolute_error: 43227.8341 - val_loss: 3272115158.5185 - val_mean_absolute_error: 32521.8891
# Epoch 77/100
# 567/567 [==============================] - 0s 339us/step - loss: 4792598621.6861 - mean_absolute_error: 42067.2718 - val_loss: 3327753130.0082 - val_mean_absolute_error: 32379.9351
# Epoch 78/100
# 567/567 [==============================] - 0s 341us/step - loss: 5359799608.3245 - mean_absolute_error: 42104.0025 - val_loss: 3312647633.9753 - val_mean_absolute_error: 32303.8074
# Epoch 79/100
# 567/567 [==============================] - 0s 334us/step - loss: 7035116894.5891 - mean_absolute_error: 45549.0099 - val_loss: 3486505245.7613 - val_mean_absolute_error: 33200.7373
# Epoch 80/100
# 567/567 [==============================] - 0s 339us/step - loss: 6218144672.7337 - mean_absolute_error: 42659.0147 - val_loss: 3443526540.9053 - val_mean_absolute_error: 32820.1887
# Epoch 81/100
# 567/567 [==============================] - 0s 342us/step - loss: 4203710063.2945 - mean_absolute_error: 40618.0905 - val_loss: 3468703331.6214 - val_mean_absolute_error: 32983.6831
# Epoch 82/100
# 567/567 [==============================] - 0s 342us/step - loss: 4801488621.1499 - mean_absolute_error: 42222.0224 - val_loss: 3458208184.0988 - val_mean_absolute_error: 32659.4164
# Epoch 83/100
# 567/567 [==============================] - 0s 355us/step - loss: 4325072320.6772 - mean_absolute_error: 41947.9033 - val_loss: 3271602616.4938 - val_mean_absolute_error: 32357.2575
# Epoch 84/100
# 567/567 [==============================] - 0s 335us/step - loss: 5011078644.2610 - mean_absolute_error: 43276.9377 - val_loss: 3165716484.2140 - val_mean_absolute_error: 31927.7813
# Epoch 85/100
# 567/567 [==============================] - 0s 366us/step - loss: 5303952810.2152 - mean_absolute_error: 42199.6799 - val_loss: 3314223478.0576 - val_mean_absolute_error: 31997.4053
# Epoch 86/100
# 567/567 [==============================] - 0s 340us/step - loss: 4989224468.0917 - mean_absolute_error: 41512.1702 - val_loss: 3291987965.7613 - val_mean_absolute_error: 32174.9410
# Epoch 87/100
# 567/567 [==============================] - 0s 338us/step - loss: 4558180707.8942 - mean_absolute_error: 41003.2655 - val_loss: 3417845780.2140 - val_mean_absolute_error: 32260.1414
# Epoch 88/100
# 567/567 [==============================] - 0s 337us/step - loss: 4711739001.0018 - mean_absolute_error: 41346.4417 - val_loss: 3595318265.0206 - val_mean_absolute_error: 32808.1381
# Epoch 89/100
# 567/567 [==============================] - 0s 340us/step - loss: 4340909133.8836 - mean_absolute_error: 42604.6695 - val_loss: 3369512229.6626 - val_mean_absolute_error: 32869.5053
# Epoch 90/100
# 567/567 [==============================] - 0s 350us/step - loss: 4288223117.1499 - mean_absolute_error: 41834.8675 - val_loss: 3279781219.0288 - val_mean_absolute_error: 32006.6500
# Epoch 91/100
# 567/567 [==============================] - 0s 367us/step - loss: 5893526719.5485 - mean_absolute_error: 42180.6100 - val_loss: 3558663268.4774 - val_mean_absolute_error: 32885.1584
# Epoch 92/100
# 567/567 [==============================] - 0s 335us/step - loss: 4895210298.2434 - mean_absolute_error: 41461.9513 - val_loss: 3613354747.0617 - val_mean_absolute_error: 32931.4475
# Epoch 93/100
# 567/567 [==============================] - 0s 341us/step - loss: 5379352549.8131 - mean_absolute_error: 43988.3999 - val_loss: 3738614680.4938 - val_mean_absolute_error: 32843.1385
# Epoch 94/100
# 567/567 [==============================] - 0s 337us/step - loss: 4228213273.2840 - mean_absolute_error: 40783.5972 - val_loss: 3490540125.4979 - val_mean_absolute_error: 32425.9344
# Epoch 95/100
# 567/567 [==============================] - 0s 330us/step - loss: 4515958244.1199 - mean_absolute_error: 41579.8830 - val_loss: 3559342977.7119 - val_mean_absolute_error: 32414.5179
# Epoch 96/100
# 567/567 [==============================] - 0s 334us/step - loss: 4420583594.7795 - mean_absolute_error: 40860.7780 - val_loss: 3809174934.6502 - val_mean_absolute_error: 32441.9621
# Epoch 97/100
# 567/567 [==============================] - 0s 334us/step - loss: 4756033720.2116 - mean_absolute_error: 41504.2686 - val_loss: 3578013632.5267 - val_mean_absolute_error: 32331.3190
# Epoch 98/100
# 567/567 [==============================] - 0s 331us/step - loss: 4047349387.7390 - mean_absolute_error: 40137.6688 - val_loss: 3656287219.5556 - val_mean_absolute_error: 32236.3495
# Epoch 99/100
# 567/567 [==============================] - 0s 361us/step - loss: 4718917282.3139 - mean_absolute_error: 44763.1706 - val_loss: 3823206765.7613 - val_mean_absolute_error: 33288.7685
# Epoch 100/100
# 567/567 [==============================] - 0s 340us/step - loss: 3487561123.8942 - mean_absolute_error: 41099.4643 - val_loss: 3434862651.2593 - val_mean_absolute_error: 32318.6589

# %% [markdown]
# Looking again at the `Mean Absolute Error` plot we can see no signs of overfitting, so the regularisation has worked! Now evaluating again using the test-set.

# %%
from sklearn.metrics import mean_absolute_error

predictions = model.predict(X_test)

mae = mean_absolute_error(y_test, predictions)

print("Total error: $%.2f" %mae)
# Out:
# Total error: $35309.45

# %% [markdown]
# The total error is reduced. The process of finding the ideal parameters for a particular network is not straightforward, not only because there are so many parameters and modules to choose from, but also because the parameters interact. The ideal learning rate for one network architecture may not be the same if we add more layers or implement regularisation techniques. Generally we will start with a simple network with two hidden layers with geometrically decreasing number of neurons. We can then gradually make the network more complex until we see the signs of slight overfitting. Regularisation methods can then be used to improve performance on the test set.

# %% [markdown]
# ## 7.7 Optimising the Network: Backpropagation
#
# **NB: This section is highly mathematical and is presented only for those curious about the details of the backpropagation algorithm. Those not comfortable in vector calculus can safely skip it**
#
# ### 7.7.1 Backpropagation with One Hidden Layer
#
# Using the same notation as above we can write the Mean Squared Error of a network as:
#
# $$C_0 = \frac{1}{n}\sum_{j} (a_j^L-y_j)^2$$
#
# Where $a_j^L$ is the activation of the $j$-th neuron in the $L$-th (output) layer, and $y_j$ is the ground-truth corresponding to the target variable in the training set. The activation of a neuron $j$ in layer $L$ is given by:
#
# $$ a^L_j = \sigma(z^L_j) $$
#
# $$ z^L_j = \sum_k a^{L-1}_k w^L_{jk} + b^L_j $$
#
# We want to find the path of steepest descent in the cost function, so we're interested in calculating the *gradient*, $\nabla C_0$. The gradient is the vector of elements $ \frac{\partial C_0}{\partial w^L_{jk}}$ which has a direction parallel to the path of steepest descent and a magnitude proportional to the rate of change of the cost function in that direction.
#
# Using the chain rule $\frac{\partial x}{\partial z} = \frac{\partial x}{\partial y}\frac{\partial y}{\partial z} $ twice, we get:
#
# $$ \frac{\partial C_0}{\partial w^L_{jk}} = \frac{\partial C_0}{\partial a^L_j} \frac{\partial a^L_j}{\partial z^L_j} \frac{\partial z^L_j}{\partial w^L_{jk}} $$
#
# Each of the derivatives on the RHS is easily evaluated:
#
# $$ \frac{\partial C_0}{\partial a^L_j} = 2(a^L_j-y) $$
#
# $$ \frac{\partial a^L_j}{\partial z^L_j} = \sigma'(z^L_j) $$
#
# $$ \frac{\partial z^L_j}{\partial w^L_{jk}} = a^{L-1}_k $$
#
# And we get:
#
# $$ \frac{\partial C_0}{\partial w^L_{jk}} = 2(a^L_j-y) \sigma'(z^L_j) a^{L-1}_k $$
#
# Having evaluated the gradients, we can easily update the weights $L$ according to the learning step $\alpha$:
#
# $$ w^L_{jk} \rightarrow w^L_{jk} - \alpha \frac{\partial C_0}{\partial w^L_{jk}} $$
#
# To update the weights in the previous layers, we need to propagate the error backwards. We first find the gradient with respect to the activations in the previous layer:
#
# $$ \frac{\partial C_0}{\partial a^{L-1}_k} = \sum_{j=0}^{L-1}  \frac{\partial C_0}{\partial a^L_j} \frac{\partial a^L_j}{\partial z^L_j} \frac{\partial z^L_j}{\partial a^{L-1}_{k}} $$
#
# Which can be evaluated as:
#
# $$ \frac{\partial C_0}{\partial a^{L-1}_k} = \sum_{j=0}^{L-1}  \sigma'(z^L_j)(a^L_j - y) w^L_{jk} $$
#
# Next we need to identify the gradient with respect to the weights in the previous layer. We use the chain rule again and multiply by $\frac{\partial a^{L-1}_k}{\partial w^{L-1}_{ik}} = \sigma'(z^{L-1}_k)a^{L-2}_k$:
#
# $$ \frac{\partial C_0}{\partial w^{L-1}_{ik}} = \sum_{j=0}^{L-1}  \sigma'(z^L_j)(a^L_j - y) w^L_{jk} \sigma'(z^{L-1}_k)a^{L-2}_i $$
#
# And we have the update rule for the hidden layer weights:
#
# $$ w^{L-1}_{jk} \rightarrow w^{L-1}_{jk} - \alpha \frac{\partial C_0}{\partial w^{L-1}_{jk}} $$
#
# The process of updating biases follows a similar procedure, using the chain rule to find the gradient at each step. Finding the gradient with respect to the biases is somewhat easier since $\frac{\partial z^L_j}{\partial b^L_{j}} = 1$.
#
# ### 7.7.2 Extending to a Multilayer Network
#
# We can simplify this process by defining the output error $\delta^l_j = \nabla^l_aC_j \circ \sigma'(z^L_j) $, where $\circ$ represents the Hadamard product, or elementwise multiplication of vector elements. This also allows us to generalise to an arbitrary number of layers. Now we can write the output error of a layer in terms of the ourput error of the subsequent layer:
#
# $$ \delta^{l-1}_j = (w^l)^T\delta^l_j \circ \sigma'(z^{l-1}_j) $$
#
# And the gradients in terms of weights can be defined as:
#
# $$\nabla^l_w = \delta^l_j a^{l-1}_k$$
#
# $$\nabla^l_b = \delta^l_j$$
#
# We get the general update rules for backpropagation:
#
# $$ w^{l}_{jk} \rightarrow w^{l}_{jk} - \alpha (w^{l+1})^T \delta^{l+1}_j \circ \sigma'(z^{l}_j) a^{l-1}_k $$
#
# $$ b^{l}_{j} \rightarrow b^{l}_{j} - \alpha (w^{l+1})^T \delta^{l+1}_j \circ \sigma'(z^{l}_j) $$
